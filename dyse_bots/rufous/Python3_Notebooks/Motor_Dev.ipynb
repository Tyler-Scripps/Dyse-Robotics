# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook

# %% [markdown]
# # Notes
#  - kv = RPM/voltage

# %%
class BLDC_Motor:
    def __init__(self, n, p, height, statorRadius, rotorRadius, kv):
        self.kv = kv
        self.offset = 0.0
        self.velocity = 0.0
        self.rotorPoles = np.linspace(0,2*np.pi,p)
        self.statorPoles = np.linspace(0,2*np.pi,n)
        self.rotorRadius = rotorRadius
        self.statorRadius = statorRadius
        
    def getTorque(self, v, signal):
        
        
    def step(self, v, t, signal):
        torque = getTorque(v, signal)
        self.velocity += torque * t
        self.offset += (self.velocity * t) + (torque / m * t^2 / 2)

# %%
def render(motor):
    axes = plt.axes()
    x = []
    y = []
    for p in motor.rotorPoles:
        x.append(motor.rotorRadius * np.sin(p + motor.offset))
        y.append(motor.rotorRadius * np.cos(p + motor.offset))
    axes.scatter(x,y,c='r',label='Rotor Poles')
    axes.scatter(x[0],y[0],c='y')

    x = []
    y = []
    for n in motor.statorPoles:
        x.append(motor.statorRadius * np.sin(n))
        y.append(motor.statorRadius * np.cos(n))
    axes.scatter(x,y,c='b',label='Stator Poles')
    
    axes.set_aspect('equal')
    
    plt.xlim(-2 * motor.statorRadius, 2 * motor.statorRadius)
    plt.ylim(-2 * motor.statorRadius, 2 * motor.statorRadius)
    plt.legend()
    plt.show()

# %%
m1 = BLDC_Motor(12, 14, 5, 3, 4, 2300)
for i in range(10):
    m1.step(11.1, 0.001, 'abc')
render(m1)
# Out:
# <img src="data:image/png;base64,..." width="640">
